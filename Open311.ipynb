# %%
import open311SNSL
# Out:
# In open311

# %%
help(open311SNSL)
# Out:
# Help on module open311SNSL:
#
# NAME
#     open311SNSL - Open311 API Library
#
# FILE
#     /home/freegnu/env/freegnu/local/lib/python2.7/site-packages/open311SNSL.py
#
# CLASSES
#     service
#     serviceList
#
#     class service
#      |  Methods defined here:
#      |
#      |  __init__(self, ID, Key, service_id)
#      |      (Creating Service Object)
#      |
#      |      obj = Open311SNSL.service('API ID ','API Key','serv_id')
#      |
#      |      obj = Open311SNSL.service('12345','987654','20-4-7')
#      |
#      |  getService(self, contentType)
#      |      (Search service based on service ID)
#      |
#      |      (Examples)
#      |
#      |      object.getService(object.json)
#      |              ==> Searches for service based on ID : Output JSON
#      |      object.getService(object.xml)
#      |              ==> Searches for service based on ID : Output XML
#      |
#      |  validation(self, statusCode)
# ...
